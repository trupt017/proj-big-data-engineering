# %%
import random
import pandas as pd
from faker import Faker
import pyodbc

# %%
fake = Faker()

# %%
# Step 1: FMCG departments and categories
departments = {
    "Beverages": ["Soft Drinks", "Juices", "Bottled Water", "Tea & Coffee"],
    "Snacks & Confectionery": ["Chips", "Biscuits", "Chocolates", "Nuts & Dry Fruits"],
    "Dairy Products": ["Milk", "Cheese", "Yogurt", "Butter"],
    "Personal Care": ["Shampoo", "Soap", "Deodorants", "Toothpaste"],
    "Household Cleaning": ["Detergents", "Disinfectants", "Dishwashing", "Air Fresheners"],
    "Health & Wellness": ["Supplements", "Vitamins", "First Aid", "Sanitary Products"],
    "Packaged Foods": ["Instant Noodles", "Ready Meals", "Canned Goods", "Cooking Pastes"],
    "Baby Care": ["Diapers", "Baby Food", "Baby Lotion", "Wipes"],
    "Pet Care": ["Pet Food", "Pet Shampoo", "Pet Toys"],
    "Stationery & Supplies": ["Pens", "Notebooks", "Glue", "Markers"]
}

# %%
# Step 2: Generate the hierarchy
records = []
item_id_counter = 10000  # Starting item ID

for dept, categories in departments.items():
    for cat in categories:
        num_items = random.randint(10, 20)
        for _ in range(num_items):
            item_id = f"ITM{item_id_counter}"
            item_name = fake.unique.word().capitalize() + " " + cat[:-1]  # e.g., "Fresh Biscuit"
            records.append({
                "department": dept,
                "category": cat,
                "item_id": item_id,
                "item_name": item_name
            })
            item_id_counter += 1

# Step 3: Create DataFrame and save
df = pd.DataFrame(records)
# df.to_csv("product_hierarchy.csv", index=False)

# print(f"Generated {len(df)} items across departments.")

# %%
df
# Out:
#                 department     category   item_id             item_name
# 0                Beverages  Soft Drinks  ITM10000     Leader Soft Drink
# 1                Beverages  Soft Drinks  ITM10001  Agreement Soft Drink
# 2                Beverages  Soft Drinks  ITM10002     Ground Soft Drink
# 3                Beverages  Soft Drinks  ITM10003       Hair Soft Drink
# 4                Beverages  Soft Drinks  ITM10004     Amount Soft Drink
# ..                     ...          ...       ...                   ...
# 540  Stationery & Supplies      Markers  ITM10540         Appear Marker
# 541  Stationery & Supplies      Markers  ITM10541             As Marker
# 542  Stationery & Supplies      Markers  ITM10542        Because Marker
# 543  Stationery & Supplies      Markers  ITM10543            Ask Marker
# 544  Stationery & Supplies      Markers  ITM10544           Next Marker
#
# [545 rows x 4 columns]

# %%
#  SQL Server connection details
server = 'localhost'        # Change if using a named instance e.g., 'localhost\SQLEXPRESS'
database = 'dev_FMCG_db'        # Database to create/use
username = 'sa'             # SQL Server username
password = 'sqlserver@Trupt1725' # SQL Server password

# %%
# Connect to SQL Server (master DB to create a new DB)
conn_master = pyodbc.connect(
    f'DRIVER={{ODBC Driver 17 for SQL Server}};SERVER={server};UID={username};PWD={password}'
)
conn_master.autocommit = True
cursor_master = conn_master.cursor()

# %%
# Create database if not exists
cursor_master.execute(f"IF NOT EXISTS (SELECT name FROM sys.databases WHERE name = '{database}') CREATE DATABASE {database}")
print(f"Database '{database}' ready.")

cursor_master.close()
conn_master.close()
# Out:
# Database 'dev_FMCG_db' ready.

# %%
# Step 3: Connect to target DB and create table
conn = pyodbc.connect(
    f'DRIVER={{ODBC Driver 17 for SQL Server}};SERVER={server};DATABASE={database};UID={username};PWD={password}'
)
cursor = conn.cursor()

# %%
# Create table if not exists
cursor.execute("""
IF NOT EXISTS (SELECT * FROM sysobjects WHERE name='product_hierarchy' AND xtype='U')
CREATE TABLE product_hierarchy (
    department NVARCHAR(100),
    category NVARCHAR(100),
    item_id NVARCHAR(20) PRIMARY KEY,
    item_name NVARCHAR(200)
)
""")
conn.commit()

# %%
# Step 4: Insert data
for row in records:
    cursor.execute("""
    INSERT INTO product_hierarchy (department, category, item_id, item_name)
    VALUES (?, ?, ?, ?)
    """, row["department"], row["category"], row["item_id"], row["item_name"])

conn.commit()
cursor.close()
conn.close()
# Out:
# {'department': 'Beverages', 'category': 'Soft Drinks', 'item_id': 'ITM10000', 'item_name': 'Leader Soft Drink'}
# {'department': 'Beverages', 'category': 'Soft Drinks', 'item_id': 'ITM10001', 'item_name': 'Agreement Soft Drink'}
# {'department': 'Beverages', 'category': 'Soft Drinks', 'item_id': 'ITM10002', 'item_name': 'Ground Soft Drink'}
# {'department': 'Beverages', 'category': 'Soft Drinks', 'item_id': 'ITM10003', 'item_name': 'Hair Soft Drink'}
# {'department': 'Beverages', 'category': 'Soft Drinks', 'item_id': 'ITM10004', 'item_name': 'Amount Soft Drink'}
# {'department': 'Beverages', 'category': 'Soft Drinks', 'item_id': 'ITM10005', 'item_name': 'Raise Soft Drink'}
# {'department': 'Beverages', 'category': 'Soft Drinks', 'item_id': 'ITM10006', 'item_name': 'Thought Soft Drink'}
# {'department': 'Beverages', 'category': 'Soft Drinks', 'item_id': 'ITM10007', 'item_name': 'Task Soft Drink'}
# {'department': 'Beverages', 'category': 'Soft Drinks', 'item_id': 'ITM10008', 'item_name': 'Agency Soft Drink'}
# {'department': 'Beverages', 'category': 'Soft Drinks', 'item_id': 'ITM10009', 'item_name': 'Really Soft Drink'}
# {'department': 'Beverages', 'category': 'Soft Drinks', 'item_id': 'ITM10010', 'item_name': 'Week Soft Drink'}
# {'department': 'Beverages', 'category': 'Soft Drinks', 'item_id': 'ITM10011', 'item_name': 'Step Soft Drink'}
# {'department': 'Beverages', 'category': 'Soft Drinks', 'item_id': 'ITM10012', 'item_name': 'Congress Soft Drink'}
# {'department': 'Beverages', 'category': 'Juices', 'item_id': 'ITM10013', 'item_name': 'Face Juice'}
# {'department': 'Beverages', 'category': 'Juices', 'item_id': 'ITM10014', 'item_name': 'Why Juice'}
# {'department': 'Beverages', 'category': 'Juices', 'item_id': 'ITM10015', 'item_name': 'Piece Juice'}
# {'department': 'Beverages', 'category': 'Juices', 'item_id': 'ITM10016', 'item_name': 'Charge Juice'}
# {'department': 'Beverages', 'category': 'Juices', 'item_id': 'ITM10017', 'item_name': 'Consumer Juice'}
# {'department': 'Beverages', 'category': 'Juices', 'item_id': 'ITM10018', 'item_name': 'Past Juice'}
# {'department': 'Beverages', 'category': 'Juices', 'item_id': 'ITM10019', 'item_name': 'Republican Juice'}
# {'department': 'Beverages', 'category': 'Juices', 'item_id': 'ITM10020', 'item_name': 'Second Juice'}
# {'department': 'Beverages', 'category': 'Juices', 'item_id': 'ITM10021', 'item_name': 'Adult Juice'}
# {'department': 'Beverages', 'category': 'Juices', 'item_id': 'ITM10022', 'item_name': 'Character Juice'}
# {'department': 'Beverages', 'category': 'Juices', 'item_id': 'ITM10023', 'item_name': 'Finally Juice'}
# {'department': 'Beverages', 'category': 'Juices', 'item_id': 'ITM10024', 'item_name': 'State Juice'}
# {'department': 'Beverages', 'category': 'Bottled Water', 'item_id': 'ITM10025', 'item_name': 'Beat Bottled Wate'}
# {'department': 'Beverages', 'category': 'Bottled Water', 'item_id': 'ITM10026', 'item_name': 'Southern Bottled Wate'}
# {'department': 'Beverages', 'category': 'Bottled Water', 'item_id': 'ITM10027', 'item_name': 'Black Bottled Wate'}
# {'department': 'Beverages', 'category': 'Bottled Water', 'item_id': 'ITM10028', 'item_name': 'So Bottled Wate'}
# {'department': 'Beverages', 'category': 'Bottled Water', 'item_id': 'ITM10029', 'item_name': 'Just Bottled Wate'}
# {'department': 'Beverages', 'category': 'Bottled Water', 'item_id': 'ITM10030', 'item_name': 'Movement Bottled Wate'}
# {'department': 'Beverages', 'category': 'Bottled Water', 'item_id': 'ITM10031', 'item_name': 'Difference Bottled Wate'}
# {'department': 'Beverages', 'category': 'Bottled Water', 'item_id': 'ITM10032', 'item_name': 'Land Bottled Wate'}
# {'department': 'Beverages', 'category': 'Bottled Water', 'item_id': 'ITM10033', 'item_name': 'Firm Bottled Wate'}
# {'department': 'Beverages', 'category': 'Bottled Water', 'item_id': 'ITM10034', 'item_name': 'Close Bottled Wate'}
# {'department': 'Beverages', 'category': 'Tea & Coffee', 'item_id': 'ITM10035', 'item_name': 'Wind Tea & Coffe'}
# {'department': 'Beverages', 'category': 'Tea & Coffee', 'item_id': 'ITM10036', 'item_name': 'Investment Tea & Coffe'}
# {'department': 'Beverages', 'category': 'Tea & Coffee', 'item_id': 'ITM10037', 'item_name': 'Air Tea & Coffe'}
# {'department': 'Beverages', 'category': 'Tea & Coffee', 'item_id': 'ITM10038', 'item_name': 'Country Tea & Coffe'}
# {'department': 'Beverages', 'category': 'Tea & Coffee', 'item_id': 'ITM10039', 'item_name': 'Act Tea & Coffe'}
# {'department': 'Beverages', 'category': 'Tea & Coffee', 'item_id': 'ITM10040', 'item_name': 'Speech Tea & Coffe'}
# {'department': 'Beverages', 'category': 'Tea & Coffee', 'item_id': 'ITM10041', 'item_name': 'Now Tea & Coffe'}
# {'department': 'Beverages', 'category': 'Tea & Coffee', 'item_id': 'ITM10042', 'item_name': 'Later Tea & Coffe'}
# {'department': 'Beverages', 'category': 'Tea & Coffee', 'item_id': 'ITM10043', 'item_name': 'Walk Tea & Coffe'}
# {'department': 'Beverages', 'category': 'Tea & Coffee', 'item_id': 'ITM10044', 'item_name': 'Pass Tea & Coffe'}
# {'department': 'Beverages', 'category': 'Tea & Coffee', 'item_id': 'ITM10045', 'item_name': 'Conference Tea & Coffe'}
# {'department': 'Beverages', 'category': 'Tea & Coffee', 'item_id': 'ITM10046', 'item_name': 'Which Tea & Coffe'}
# {'department': 'Beverages', 'category': 'Tea & Coffee', 'item_id': 'ITM10047', 'item_name': 'Owner Tea & Coffe'}
# {'department': 'Beverages', 'category': 'Tea & Coffee', 'item_id': 'ITM10048', 'item_name': 'Treatment Tea & Coffe'}
# {'department': 'Beverages', 'category': 'Tea & Coffee', 'item_id': 'ITM10049', 'item_name': 'Nearly Tea & Coffe'}
# {'department': 'Beverages', 'category': 'Tea & Coffee', 'item_id': 'ITM10050', 'item_name': 'Rich Tea & Coffe'}
# {'department': 'Beverages', 'category': 'Tea & Coffee', 'item_id': 'ITM10051', 'item_name': 'Decide Tea & Coffe'}
# {'department': 'Beverages', 'category': 'Tea & Coffee', 'item_id': 'ITM10052', 'item_name': 'Quality Tea & Coffe'}
# {'department': 'Beverages', 'category': 'Tea & Coffee', 'item_id': 'ITM10053', 'item_name': 'Point Tea & Coffe'}
# {'department': 'Beverages', 'category': 'Tea & Coffee', 'item_id': 'ITM10054', 'item_name': 'International Tea & Coffe'}
# {'department': 'Snacks & Confectionery', 'category': 'Chips', 'item_id': 'ITM10055', 'item_name': 'Many Chip'}
# {'department': 'Snacks & Confectionery', 'category': 'Chips', 'item_id': 'ITM10056', 'item_name': 'Control Chip'}
# {'department': 'Snacks & Confectionery', 'category': 'Chips', 'item_id': 'ITM10057', 'item_name': 'Guy Chip'}
# {'department': 'Snacks & Confectionery', 'category': 'Chips', 'item_id': 'ITM10058', 'item_name': 'Real Chip'}
# {'department': 'Snacks & Confectionery', 'category': 'Chips', 'item_id': 'ITM10059', 'item_name': 'Give Chip'}
# {'department': 'Snacks & Confectionery', 'category': 'Chips', 'item_id': 'ITM10060', 'item_name': 'Grow Chip'}
# {'department': 'Snacks & Confectionery', 'category': 'Chips', 'item_id': 'ITM10061', 'item_name': 'Her Chip'}
# {'department': 'Snacks & Confectionery', 'category': 'Chips', 'item_id': 'ITM10062', 'item_name': 'Wish Chip'}
# {'department': 'Snacks & Confectionery', 'category': 'Chips', 'item_id': 'ITM10063', 'item_name': 'Edge Chip'}
# {'department': 'Snacks & Confectionery', 'category': 'Chips', 'item_id': 'ITM10064', 'item_name': 'Value Chip'}
# {'department': 'Snacks & Confectionery', 'category': 'Biscuits', 'item_id': 'ITM10065', 'item_name': 'Reason Biscuit'}
# {'department': 'Snacks & Confectionery', 'category': 'Biscuits', 'item_id': 'ITM10066', 'item_name': 'Smile Biscuit'}
# {'department': 'Snacks & Confectionery', 'category': 'Biscuits', 'item_id': 'ITM10067', 'item_name': 'Ready Biscuit'}
# {'department': 'Snacks & Confectionery', 'category': 'Biscuits', 'item_id': 'ITM10068', 'item_name': 'While Biscuit'}
# {'department': 'Snacks & Confectionery', 'category': 'Biscuits', 'item_id': 'ITM10069', 'item_name': 'Few Biscuit'}
# {'department': 'Snacks & Confectionery', 'category': 'Biscuits', 'item_id': 'ITM10070', 'item_name': 'Dark Biscuit'}
# {'department': 'Snacks & Confectionery', 'category': 'Biscuits', 'item_id': 'ITM10071', 'item_name': 'Help Biscuit'}
# {'department': 'Snacks & Confectionery', 'category': 'Biscuits', 'item_id': 'ITM10072', 'item_name': 'Magazine Biscuit'}
# {'department': 'Snacks & Confectionery', 'category': 'Biscuits', 'item_id': 'ITM10073', 'item_name': 'Rate Biscuit'}
# {'department': 'Snacks & Confectionery', 'category': 'Biscuits', 'item_id': 'ITM10074', 'item_name': 'Reality Biscuit'}
# {'department': 'Snacks & Confectionery', 'category': 'Chocolates', 'item_id': 'ITM10075', 'item_name': 'Issue Chocolate'}
# {'department': 'Snacks & Confectionery', 'category': 'Chocolates', 'item_id': 'ITM10076', 'item_name': 'Record Chocolate'}
# {'department': 'Snacks & Confectionery', 'category': 'Chocolates', 'item_id': 'ITM10077', 'item_name': 'Although Chocolate'}
# {'department': 'Snacks & Confectionery', 'category': 'Chocolates', 'item_id': 'ITM10078', 'item_name': 'Machine Chocolate'}
# {'department': 'Snacks & Confectionery', 'category': 'Chocolates', 'item_id': 'ITM10079', 'item_name': 'Decade Chocolate'}
# {'department': 'Snacks & Confectionery', 'category': 'Chocolates', 'item_id': 'ITM10080', 'item_name': 'Sign Chocolate'}
# {'department': 'Snacks & Confectionery', 'category': 'Chocolates', 'item_id': 'ITM10081', 'item_name': 'Money Chocolate'}
# {'department': 'Snacks & Confectionery', 'category': 'Chocolates', 'item_id': 'ITM10082', 'item_name': 'Receive Chocolate'}
# {'department': 'Snacks & Confectionery', 'category': 'Chocolates', 'item_id': 'ITM10083', 'item_name': 'Sell Chocolate'}
# {'department': 'Snacks & Confectionery', 'category': 'Chocolates', 'item_id': 'ITM10084', 'item_name': 'When Chocolate'}
# {'department': 'Snacks & Confectionery', 'category': 'Chocolates', 'item_id': 'ITM10085', 'item_name': 'May Chocolate'}
# {'department': 'Snacks & Confectionery', 'category': 'Chocolates', 'item_id': 'ITM10086', 'item_name': 'Property Chocolate'}
# {'department': 'Snacks & Confectionery', 'category': 'Chocolates', 'item_id': 'ITM10087', 'item_name': 'Tough Chocolate'}
# {'department': 'Snacks & Confectionery', 'category': 'Chocolates', 'item_id': 'ITM10088', 'item_name': 'Hospital Chocolate'}
# {'department': 'Snacks & Confectionery', 'category': 'Chocolates', 'item_id': 'ITM10089', 'item_name': 'Between Chocolate'}
# {'department': 'Snacks & Confectionery', 'category': 'Chocolates', 'item_id': 'ITM10090', 'item_name': 'Remember Chocolate'}
# {'department': 'Snacks & Confectionery', 'category': 'Nuts & Dry Fruits', 'item_id': 'ITM10091', 'item_name': 'Miss Nuts & Dry Fruit'}
# {'department': 'Snacks & Confectionery', 'category': 'Nuts & Dry Fruits', 'item_id': 'ITM10092', 'item_name': 'Day Nuts & Dry Fruit'}
# {'department': 'Snacks & Confectionery', 'category': 'Nuts & Dry Fruits', 'item_id': 'ITM10093', 'item_name': 'Every Nuts & Dry Fruit'}
# {'department': 'Snacks & Confectionery', 'category': 'Nuts & Dry Fruits', 'item_id': 'ITM10094', 'item_name': 'Science Nuts & Dry Fruit'}
# {'department': 'Snacks & Confectionery', 'category': 'Nuts & Dry Fruits', 'item_id': 'ITM10095', 'item_name': 'Similar Nuts & Dry Fruit'}
# {'department': 'Snacks & Confectionery', 'category': 'Nuts & Dry Fruits', 'item_id': 'ITM10096', 'item_name': 'Attorney Nuts & Dry Fruit'}
# {'department': 'Snacks & Confectionery', 'category': 'Nuts & Dry Fruits', 'item_id': 'ITM10097', 'item_name': 'Finish Nuts & Dry Fruit'}
# {'department': 'Snacks & Confectionery', 'category': 'Nuts & Dry Fruits', 'item_id': 'ITM10098', 'item_name': 'Poor Nuts & Dry Fruit'}
# {'department': 'Snacks & Confectionery', 'category': 'Nuts & Dry Fruits', 'item_id': 'ITM10099', 'item_name': 'Describe Nuts & Dry Fruit'}
# {'department': 'Snacks & Confectionery', 'category': 'Nuts & Dry Fruits', 'item_id': 'ITM10100', 'item_name': 'Performance Nuts & Dry Fruit'}
# {'department': 'Snacks & Confectionery', 'category': 'Nuts & Dry Fruits', 'item_id': 'ITM10101', 'item_name': 'Security Nuts & Dry Fruit'}
# {'department': 'Snacks & Confectionery', 'category': 'Nuts & Dry Fruits', 'item_id': 'ITM10102', 'item_name': 'Strong Nuts & Dry Fruit'}
# {'department': 'Snacks & Confectionery', 'category': 'Nuts & Dry Fruits', 'item_id': 'ITM10103', 'item_name': 'Site Nuts & Dry Fruit'}
# {'department': 'Snacks & Confectionery', 'category': 'Nuts & Dry Fruits', 'item_id': 'ITM10104', 'item_name': 'Since Nuts & Dry Fruit'}
# {'department': 'Snacks & Confectionery', 'category': 'Nuts & Dry Fruits', 'item_id': 'ITM10105', 'item_name': 'Remain Nuts & Dry Fruit'}
# {'department': 'Snacks & Confectionery', 'category': 'Nuts & Dry Fruits', 'item_id': 'ITM10106', 'item_name': 'Trial Nuts & Dry Fruit'}
# {'department': 'Snacks & Confectionery', 'category': 'Nuts & Dry Fruits', 'item_id': 'ITM10107', 'item_name': 'Wonder Nuts & Dry Fruit'}
# {'department': 'Snacks & Confectionery', 'category': 'Nuts & Dry Fruits', 'item_id': 'ITM10108', 'item_name': 'Return Nuts & Dry Fruit'}
# {'department': 'Snacks & Confectionery', 'category': 'Nuts & Dry Fruits', 'item_id': 'ITM10109', 'item_name': 'Much Nuts & Dry Fruit'}
# {'department': 'Dairy Products', 'category': 'Milk', 'item_id': 'ITM10110', 'item_name': 'Less Mil'}
# {'department': 'Dairy Products', 'category': 'Milk', 'item_id': 'ITM10111', 'item_name': 'Turn Mil'}
# {'department': 'Dairy Products', 'category': 'Milk', 'item_id': 'ITM10112', 'item_name': 'Spring Mil'}
# {'department': 'Dairy Products', 'category': 'Milk', 'item_id': 'ITM10113', 'item_name': 'Believe Mil'}
# {'department': 'Dairy Products', 'category': 'Milk', 'item_id': 'ITM10114', 'item_name': 'Moment Mil'}
# {'department': 'Dairy Products', 'category': 'Milk', 'item_id': 'ITM10115', 'item_name': 'Player Mil'}
# {'department': 'Dairy Products', 'category': 'Milk', 'item_id': 'ITM10116', 'item_name': 'Discover Mil'}
# {'department': 'Dairy Products', 'category': 'Milk', 'item_id': 'ITM10117', 'item_name': 'Plant Mil'}
# {'department': 'Dairy Products', 'category': 'Milk', 'item_id': 'ITM10118', 'item_name': 'Call Mil'}
# {'department': 'Dairy Products', 'category': 'Milk', 'item_id': 'ITM10119', 'item_name': 'American Mil'}
# {'department': 'Dairy Products', 'category': 'Milk', 'item_id': 'ITM10120', 'item_name': 'Floor Mil'}
# {'department': 'Dairy Products', 'category': 'Milk', 'item_id': 'ITM10121', 'item_name': 'I Mil'}
# {'department': 'Dairy Products', 'category': 'Milk', 'item_id': 'ITM10122', 'item_name': 'Art Mil'}
# {'department': 'Dairy Products', 'category': 'Milk', 'item_id': 'ITM10123', 'item_name': 'Near Mil'}
# {'department': 'Dairy Products', 'category': 'Milk', 'item_id': 'ITM10124', 'item_name': 'Able Mil'}
# {'department': 'Dairy Products', 'category': 'Milk', 'item_id': 'ITM10125', 'item_name': 'Modern Mil'}
# {'department': 'Dairy Products', 'category': 'Milk', 'item_id': 'ITM10126', 'item_name': 'Into Mil'}
# {'department': 'Dairy Products', 'category': 'Milk', 'item_id': 'ITM10127', 'item_name': 'Feel Mil'}
# {'department': 'Dairy Products', 'category': 'Milk', 'item_id': 'ITM10128', 'item_name': 'Cause Mil'}
# {'department': 'Dairy Products', 'category': 'Milk', 'item_id': 'ITM10129', 'item_name': 'Message Mil'}
# {'department': 'Dairy Products', 'category': 'Cheese', 'item_id': 'ITM10130', 'item_name': 'Tend Chees'}
# {'department': 'Dairy Products', 'category': 'Cheese', 'item_id': 'ITM10131', 'item_name': 'Book Chees'}
# {'department': 'Dairy Products', 'category': 'Cheese', 'item_id': 'ITM10132', 'item_name': 'Discussion Chees'}
# {'department': 'Dairy Products', 'category': 'Cheese', 'item_id': 'ITM10133', 'item_name': 'Fund Chees'}
# {'department': 'Dairy Products', 'category': 'Cheese', 'item_id': 'ITM10134', 'item_name': 'First Chees'}
# {'department': 'Dairy Products', 'category': 'Cheese', 'item_id': 'ITM10135', 'item_name': 'Television Chees'}
# {'department': 'Dairy Products', 'category': 'Cheese', 'item_id': 'ITM10136', 'item_name': 'Doctor Chees'}
# {'department': 'Dairy Products', 'category': 'Cheese', 'item_id': 'ITM10137', 'item_name': 'Might Chees'}
# {'department': 'Dairy Products', 'category': 'Cheese', 'item_id': 'ITM10138', 'item_name': 'Hard Chees'}
# {'department': 'Dairy Products', 'category': 'Cheese', 'item_id': 'ITM10139', 'item_name': 'Fine Chees'}
# {'department': 'Dairy Products', 'category': 'Cheese', 'item_id': 'ITM10140', 'item_name': 'Wear Chees'}
# {'department': 'Dairy Products', 'category': 'Cheese', 'item_id': 'ITM10141', 'item_name': 'Couple Chees'}
# {'department': 'Dairy Products', 'category': 'Cheese', 'item_id': 'ITM10142', 'item_name': 'Standard Chees'}
# {'department': 'Dairy Products', 'category': 'Cheese', 'item_id': 'ITM10143', 'item_name': 'Short Chees'}
# {'department': 'Dairy Products', 'category': 'Yogurt', 'item_id': 'ITM10144', 'item_name': 'Knowledge Yogur'}
# {'department': 'Dairy Products', 'category': 'Yogurt', 'item_id': 'ITM10145', 'item_name': 'Board Yogur'}
# {'department': 'Dairy Products', 'category': 'Yogurt', 'item_id': 'ITM10146', 'item_name': 'Writer Yogur'}
# {'department': 'Dairy Products', 'category': 'Yogurt', 'item_id': 'ITM10147', 'item_name': 'Food Yogur'}
# {'department': 'Dairy Products', 'category': 'Yogurt', 'item_id': 'ITM10148', 'item_name': 'Despite Yogur'}
# {'department': 'Dairy Products', 'category': 'Yogurt', 'item_id': 'ITM10149', 'item_name': 'Film Yogur'}
# {'department': 'Dairy Products', 'category': 'Yogurt', 'item_id': 'ITM10150', 'item_name': 'Who Yogur'}
# {'department': 'Dairy Products', 'category': 'Yogurt', 'item_id': 'ITM10151', 'item_name': 'Win Yogur'}
# {'department': 'Dairy Products', 'category': 'Yogurt', 'item_id': 'ITM10152', 'item_name': 'Soldier Yogur'}
# {'department': 'Dairy Products', 'category': 'Yogurt', 'item_id': 'ITM10153', 'item_name': 'Daughter Yogur'}
# {'department': 'Dairy Products', 'category': 'Yogurt', 'item_id': 'ITM10154', 'item_name': 'Church Yogur'}
# {'department': 'Dairy Products', 'category': 'Yogurt', 'item_id': 'ITM10155', 'item_name': 'Other Yogur'}
# {'department': 'Dairy Products', 'category': 'Yogurt', 'item_id': 'ITM10156', 'item_name': 'Oil Yogur'}
# {'department': 'Dairy Products', 'category': 'Yogurt', 'item_id': 'ITM10157', 'item_name': 'Carry Yogur'}
# {'department': 'Dairy Products', 'category': 'Yogurt', 'item_id': 'ITM10158', 'item_name': 'Type Yogur'}
# {'department': 'Dairy Products', 'category': 'Butter', 'item_id': 'ITM10159', 'item_name': 'Main Butte'}
# {'department': 'Dairy Products', 'category': 'Butter', 'item_id': 'ITM10160', 'item_name': 'Dream Butte'}
# {'department': 'Dairy Products', 'category': 'Butter', 'item_id': 'ITM10161', 'item_name': 'Economic Butte'}
# {'department': 'Dairy Products', 'category': 'Butter', 'item_id': 'ITM10162', 'item_name': 'Whatever Butte'}
# {'department': 'Dairy Products', 'category': 'Butter', 'item_id': 'ITM10163', 'item_name': 'Provide Butte'}
# {'department': 'Dairy Products', 'category': 'Butter', 'item_id': 'ITM10164', 'item_name': 'Up Butte'}
# {'department': 'Dairy Products', 'category': 'Butter', 'item_id': 'ITM10165', 'item_name': 'Fast Butte'}
# {'department': 'Dairy Products', 'category': 'Butter', 'item_id': 'ITM10166', 'item_name': 'Economy Butte'}
# {'department': 'Dairy Products', 'category': 'Butter', 'item_id': 'ITM10167', 'item_name': 'Big Butte'}
# {'department': 'Dairy Products', 'category': 'Butter', 'item_id': 'ITM10168', 'item_name': 'Under Butte'}
# {'department': 'Personal Care', 'category': 'Shampoo', 'item_id': 'ITM10169', 'item_name': 'Manager Shampo'}
# {'department': 'Personal Care', 'category': 'Shampoo', 'item_id': 'ITM10170', 'item_name': 'Himself Shampo'}
# {'department': 'Personal Care', 'category': 'Shampoo', 'item_id': 'ITM10171', 'item_name': 'Recent Shampo'}
# {'department': 'Personal Care', 'category': 'Shampoo', 'item_id': 'ITM10172', 'item_name': 'Cell Shampo'}
# {'department': 'Personal Care', 'category': 'Shampoo', 'item_id': 'ITM10173', 'item_name': 'By Shampo'}
# {'department': 'Personal Care', 'category': 'Shampoo', 'item_id': 'ITM10174', 'item_name': 'Thus Shampo'}
# {'department': 'Personal Care', 'category': 'Shampoo', 'item_id': 'ITM10175', 'item_name': 'Difficult Shampo'}
# {'department': 'Personal Care', 'category': 'Shampoo', 'item_id': 'ITM10176', 'item_name': 'Heart Shampo'}
# {'department': 'Personal Care', 'category': 'Shampoo', 'item_id': 'ITM10177', 'item_name': 'Continue Shampo'}
# {'department': 'Personal Care', 'category': 'Shampoo', 'item_id': 'ITM10178', 'item_name': 'Bar Shampo'}
# {'department': 'Personal Care', 'category': 'Shampoo', 'item_id': 'ITM10179', 'item_name': 'Again Shampo'}
# {'department': 'Personal Care', 'category': 'Shampoo', 'item_id': 'ITM10180', 'item_name': 'Head Shampo'}
# {'department': 'Personal Care', 'category': 'Shampoo', 'item_id': 'ITM10181', 'item_name': 'Defense Shampo'}
# {'department': 'Personal Care', 'category': 'Shampoo', 'item_id': 'ITM10182', 'item_name': 'Series Shampo'}
# {'department': 'Personal Care', 'category': 'Shampoo', 'item_id': 'ITM10183', 'item_name': 'For Shampo'}
# {'department': 'Personal Care', 'category': 'Shampoo', 'item_id': 'ITM10184', 'item_name': 'Rise Shampo'}
# {'department': 'Personal Care', 'category': 'Shampoo', 'item_id': 'ITM10185', 'item_name': 'Letter Shampo'}
# {'department': 'Personal Care', 'category': 'Shampoo', 'item_id': 'ITM10186', 'item_name': 'Begin Shampo'}
# {'department': 'Personal Care', 'category': 'Shampoo', 'item_id': 'ITM10187', 'item_name': 'Season Shampo'}
# {'department': 'Personal Care', 'category': 'Soap', 'item_id': 'ITM10188', 'item_name': 'Energy Soa'}
# {'department': 'Personal Care', 'category': 'Soap', 'item_id': 'ITM10189', 'item_name': 'Reduce Soa'}
# {'department': 'Personal Care', 'category': 'Soap', 'item_id': 'ITM10190', 'item_name': 'Body Soa'}
# {'department': 'Personal Care', 'category': 'Soap', 'item_id': 'ITM10191', 'item_name': 'Action Soa'}
# {'department': 'Personal Care', 'category': 'Soap', 'item_id': 'ITM10192', 'item_name': 'Through Soa'}
# {'department': 'Personal Care', 'category': 'Soap', 'item_id': 'ITM10193', 'item_name': 'Voice Soa'}
# {'department': 'Personal Care', 'category': 'Soap', 'item_id': 'ITM10194', 'item_name': 'Idea Soa'}
# {'department': 'Personal Care', 'category': 'Soap', 'item_id': 'ITM10195', 'item_name': 'Somebody Soa'}
# {'department': 'Personal Care', 'category': 'Soap', 'item_id': 'ITM10196', 'item_name': 'Trade Soa'}
# {'department': 'Personal Care', 'category': 'Soap', 'item_id': 'ITM10197', 'item_name': 'Perform Soa'}
# {'department': 'Personal Care', 'category': 'Deodorants', 'item_id': 'ITM10198', 'item_name': 'Prepare Deodorant'}
# {'department': 'Personal Care', 'category': 'Deodorants', 'item_id': 'ITM10199', 'item_name': 'Police Deodorant'}
# {'department': 'Personal Care', 'category': 'Deodorants', 'item_id': 'ITM10200', 'item_name': 'If Deodorant'}
# {'department': 'Personal Care', 'category': 'Deodorants', 'item_id': 'ITM10201', 'item_name': 'Occur Deodorant'}
# {'department': 'Personal Care', 'category': 'Deodorants', 'item_id': 'ITM10202', 'item_name': 'Civil Deodorant'}
# {'department': 'Personal Care', 'category': 'Deodorants', 'item_id': 'ITM10203', 'item_name': 'Put Deodorant'}
# {'department': 'Personal Care', 'category': 'Deodorants', 'item_id': 'ITM10204', 'item_name': 'Fire Deodorant'}
# {'department': 'Personal Care', 'category': 'Deodorants', 'item_id': 'ITM10205', 'item_name': 'Watch Deodorant'}
# {'department': 'Personal Care', 'category': 'Deodorants', 'item_id': 'ITM10206', 'item_name': 'Experience Deodorant'}
# {'department': 'Personal Care', 'category': 'Deodorants', 'item_id': 'ITM10207', 'item_name': 'Quickly Deodorant'}
# {'department': 'Personal Care', 'category': 'Toothpaste', 'item_id': 'ITM10208', 'item_name': 'Themselves Toothpast'}
# {'department': 'Personal Care', 'category': 'Toothpaste', 'item_id': 'ITM10209', 'item_name': 'Professor Toothpast'}
# {'department': 'Personal Care', 'category': 'Toothpaste', 'item_id': 'ITM10210', 'item_name': 'Training Toothpast'}
# {'department': 'Personal Care', 'category': 'Toothpaste', 'item_id': 'ITM10211', 'item_name': 'News Toothpast'}
# {'department': 'Personal Care', 'category': 'Toothpaste', 'item_id': 'ITM10212', 'item_name': 'Western Toothpast'}
# {'department': 'Personal Care', 'category': 'Toothpaste', 'item_id': 'ITM10213', 'item_name': 'Yourself Toothpast'}
# {'department': 'Personal Care', 'category': 'Toothpaste', 'item_id': 'ITM10214', 'item_name': 'Three Toothpast'}
# {'department': 'Personal Care', 'category': 'Toothpaste', 'item_id': 'ITM10215', 'item_name': 'Laugh Toothpast'}
# {'department': 'Personal Care', 'category': 'Toothpaste', 'item_id': 'ITM10216', 'item_name': 'Stuff Toothpast'}
# {'department': 'Personal Care', 'category': 'Toothpaste', 'item_id': 'ITM10217', 'item_name': 'Trouble Toothpast'}
# {'department': 'Personal Care', 'category': 'Toothpaste', 'item_id': 'ITM10218', 'item_name': 'Attack Toothpast'}
# {'department': 'Personal Care', 'category': 'Toothpaste', 'item_id': 'ITM10219', 'item_name': 'Business Toothpast'}
# {'department': 'Personal Care', 'category': 'Toothpaste', 'item_id': 'ITM10220', 'item_name': 'Make Toothpast'}
# {'department': 'Personal Care', 'category': 'Toothpaste', 'item_id': 'ITM10221', 'item_name': 'Suggest Toothpast'}
# {'department': 'Personal Care', 'category': 'Toothpaste', 'item_id': 'ITM10222', 'item_name': 'Send Toothpast'}
# {'department': 'Personal Care', 'category': 'Toothpaste', 'item_id': 'ITM10223', 'item_name': 'Town Toothpast'}
# {'department': 'Personal Care', 'category': 'Toothpaste', 'item_id': 'ITM10224', 'item_name': 'Movie Toothpast'}
# {'department': 'Household Cleaning', 'category': 'Detergents', 'item_id': 'ITM10225', 'item_name': 'Name Detergent'}
# {'department': 'Household Cleaning', 'category': 'Detergents', 'item_id': 'ITM10226', 'item_name': 'Professional Detergent'}
# {'department': 'Household Cleaning', 'category': 'Detergents', 'item_id': 'ITM10227', 'item_name': 'Nor Detergent'}
# {'department': 'Household Cleaning', 'category': 'Detergents', 'item_id': 'ITM10228', 'item_name': 'Stock Detergent'}
# {'department': 'Household Cleaning', 'category': 'Detergents', 'item_id': 'ITM10229', 'item_name': 'Seem Detergent'}
# {'department': 'Household Cleaning', 'category': 'Detergents', 'item_id': 'ITM10230', 'item_name': 'Stage Detergent'}
# {'department': 'Household Cleaning', 'category': 'Detergents', 'item_id': 'ITM10231', 'item_name': 'Common Detergent'}
# {'department': 'Household Cleaning', 'category': 'Detergents', 'item_id': 'ITM10232', 'item_name': 'Left Detergent'}
# {'department': 'Household Cleaning', 'category': 'Detergents', 'item_id': 'ITM10233', 'item_name': 'Tree Detergent'}
# {'department': 'Household Cleaning', 'category': 'Detergents', 'item_id': 'ITM10234', 'item_name': 'Bed Detergent'}
# {'department': 'Household Cleaning', 'category': 'Disinfectants', 'item_id': 'ITM10235', 'item_name': 'Something Disinfectant'}
# {'department': 'Household Cleaning', 'category': 'Disinfectants', 'item_id': 'ITM10236', 'item_name': 'Growth Disinfectant'}
# {'department': 'Household Cleaning', 'category': 'Disinfectants', 'item_id': 'ITM10237', 'item_name': 'Middle Disinfectant'}
# {'department': 'Household Cleaning', 'category': 'Disinfectants', 'item_id': 'ITM10238', 'item_name': 'Benefit Disinfectant'}
# {'department': 'Household Cleaning', 'category': 'Disinfectants', 'item_id': 'ITM10239', 'item_name': 'Relationship Disinfectant'}
# {'department': 'Household Cleaning', 'category': 'Disinfectants', 'item_id': 'ITM10240', 'item_name': 'Prove Disinfectant'}
# {'department': 'Household Cleaning', 'category': 'Disinfectants', 'item_id': 'ITM10241', 'item_name': 'But Disinfectant'}
# {'department': 'Household Cleaning', 'category': 'Disinfectants', 'item_id': 'ITM10242', 'item_name': 'Popular Disinfectant'}
# {'department': 'Household Cleaning', 'category': 'Disinfectants', 'item_id': 'ITM10243', 'item_name': 'Physical Disinfectant'}
# {'department': 'Household Cleaning', 'category': 'Disinfectants', 'item_id': 'ITM10244', 'item_name': 'Whether Disinfectant'}
# {'department': 'Household Cleaning', 'category': 'Disinfectants', 'item_id': 'ITM10245', 'item_name': 'Eye Disinfectant'}
# {'department': 'Household Cleaning', 'category': 'Dishwashing', 'item_id': 'ITM10246', 'item_name': 'None Dishwashin'}
# {'department': 'Household Cleaning', 'category': 'Dishwashing', 'item_id': 'ITM10247', 'item_name': 'Sometimes Dishwashin'}
# {'department': 'Household Cleaning', 'category': 'Dishwashing', 'item_id': 'ITM10248', 'item_name': 'Some Dishwashin'}
# {'department': 'Household Cleaning', 'category': 'Dishwashing', 'item_id': 'ITM10249', 'item_name': 'Price Dishwashin'}
# {'department': 'Household Cleaning', 'category': 'Dishwashing', 'item_id': 'ITM10250', 'item_name': 'Water Dishwashin'}
# {'department': 'Household Cleaning', 'category': 'Dishwashing', 'item_id': 'ITM10251', 'item_name': 'Kind Dishwashin'}
# {'department': 'Household Cleaning', 'category': 'Dishwashing', 'item_id': 'ITM10252', 'item_name': 'Drug Dishwashin'}
# {'department': 'Household Cleaning', 'category': 'Dishwashing', 'item_id': 'ITM10253', 'item_name': 'Concern Dishwashin'}
# {'department': 'Household Cleaning', 'category': 'Dishwashing', 'item_id': 'ITM10254', 'item_name': 'Our Dishwashin'}
# {'department': 'Household Cleaning', 'category': 'Dishwashing', 'item_id': 'ITM10255', 'item_name': 'Best Dishwashin'}
# {'department': 'Household Cleaning', 'category': 'Dishwashing', 'item_id': 'ITM10256', 'item_name': 'Possible Dishwashin'}
# {'department': 'Household Cleaning', 'category': 'Dishwashing', 'item_id': 'ITM10257', 'item_name': 'Realize Dishwashin'}
# {'department': 'Household Cleaning', 'category': 'Dishwashing', 'item_id': 'ITM10258', 'item_name': 'Son Dishwashin'}
# {'department': 'Household Cleaning', 'category': 'Dishwashing', 'item_id': 'ITM10259', 'item_name': 'Friend Dishwashin'}
# {'department': 'Household Cleaning', 'category': 'Dishwashing', 'item_id': 'ITM10260', 'item_name': 'Create Dishwashin'}
# {'department': 'Household Cleaning', 'category': 'Dishwashing', 'item_id': 'ITM10261', 'item_name': 'Interest Dishwashin'}
# {'department': 'Household Cleaning', 'category': 'Dishwashing', 'item_id': 'ITM10262', 'item_name': 'Outside Dishwashin'}
# {'department': 'Household Cleaning', 'category': 'Air Fresheners', 'item_id': 'ITM10263', 'item_name': 'Prevent Air Freshener'}
# {'department': 'Household Cleaning', 'category': 'Air Fresheners', 'item_id': 'ITM10264', 'item_name': 'Seven Air Freshener'}
# {'department': 'Household Cleaning', 'category': 'Air Fresheners', 'item_id': 'ITM10265', 'item_name': 'Rule Air Freshener'}
# {'department': 'Household Cleaning', 'category': 'Air Fresheners', 'item_id': 'ITM10266', 'item_name': 'Important Air Freshener'}
# {'department': 'Household Cleaning', 'category': 'Air Fresheners', 'item_id': 'ITM10267', 'item_name': 'Program Air Freshener'}
# {'department': 'Household Cleaning', 'category': 'Air Fresheners', 'item_id': 'ITM10268', 'item_name': 'College Air Freshener'}
# {'department': 'Household Cleaning', 'category': 'Air Fresheners', 'item_id': 'ITM10269', 'item_name': 'Size Air Freshener'}
# {'department': 'Household Cleaning', 'category': 'Air Fresheners', 'item_id': 'ITM10270', 'item_name': 'Forget Air Freshener'}
# {'department': 'Household Cleaning', 'category': 'Air Fresheners', 'item_id': 'ITM10271', 'item_name': 'Scientist Air Freshener'}
# {'department': 'Household Cleaning', 'category': 'Air Fresheners', 'item_id': 'ITM10272', 'item_name': 'Project Air Freshener'}
# {'department': 'Household Cleaning', 'category': 'Air Fresheners', 'item_id': 'ITM10273', 'item_name': 'Democrat Air Freshener'}
# {'department': 'Household Cleaning', 'category': 'Air Fresheners', 'item_id': 'ITM10274', 'item_name': 'Include Air Freshener'}
# {'department': 'Household Cleaning', 'category': 'Air Fresheners', 'item_id': 'ITM10275', 'item_name': 'Push Air Freshener'}
# {'department': 'Household Cleaning', 'category': 'Air Fresheners', 'item_id': 'ITM10276', 'item_name': 'Stay Air Freshener'}
# {'department': 'Health & Wellness', 'category': 'Supplements', 'item_id': 'ITM10277', 'item_name': 'Arm Supplement'}
# {'department': 'Health & Wellness', 'category': 'Supplements', 'item_id': 'ITM10278', 'item_name': 'Find Supplement'}
# {'department': 'Health & Wellness', 'category': 'Supplements', 'item_id': 'ITM10279', 'item_name': 'Soon Supplement'}
# {'department': 'Health & Wellness', 'category': 'Supplements', 'item_id': 'ITM10280', 'item_name': 'Boy Supplement'}
# {'department': 'Health & Wellness', 'category': 'Supplements', 'item_id': 'ITM10281', 'item_name': 'Always Supplement'}
# {'department': 'Health & Wellness', 'category': 'Supplements', 'item_id': 'ITM10282', 'item_name': 'World Supplement'}
# {'department': 'Health & Wellness', 'category': 'Supplements', 'item_id': 'ITM10283', 'item_name': 'Manage Supplement'}
# {'department': 'Health & Wellness', 'category': 'Supplements', 'item_id': 'ITM10284', 'item_name': 'Health Supplement'}
# {'department': 'Health & Wellness', 'category': 'Supplements', 'item_id': 'ITM10285', 'item_name': 'Parent Supplement'}
# {'department': 'Health & Wellness', 'category': 'Supplements', 'item_id': 'ITM10286', 'item_name': 'Gun Supplement'}
# {'department': 'Health & Wellness', 'category': 'Supplements', 'item_id': 'ITM10287', 'item_name': 'Seek Supplement'}
# {'department': 'Health & Wellness', 'category': 'Vitamins', 'item_id': 'ITM10288', 'item_name': 'Quite Vitamin'}
# {'department': 'Health & Wellness', 'category': 'Vitamins', 'item_id': 'ITM10289', 'item_name': 'Them Vitamin'}
# {'department': 'Health & Wellness', 'category': 'Vitamins', 'item_id': 'ITM10290', 'item_name': 'Herself Vitamin'}
# {'department': 'Health & Wellness', 'category': 'Vitamins', 'item_id': 'ITM10291', 'item_name': 'Fight Vitamin'}
# {'department': 'Health & Wellness', 'category': 'Vitamins', 'item_id': 'ITM10292', 'item_name': 'Have Vitamin'}
# {'department': 'Health & Wellness', 'category': 'Vitamins', 'item_id': 'ITM10293', 'item_name': 'Cup Vitamin'}
# {'department': 'Health & Wellness', 'category': 'Vitamins', 'item_id': 'ITM10294', 'item_name': 'Development Vitamin'}
# {'department': 'Health & Wellness', 'category': 'Vitamins', 'item_id': 'ITM10295', 'item_name': 'Leg Vitamin'}
# {'department': 'Health & Wellness', 'category': 'Vitamins', 'item_id': 'ITM10296', 'item_name': 'Necessary Vitamin'}
# {'department': 'Health & Wellness', 'category': 'Vitamins', 'item_id': 'ITM10297', 'item_name': 'Court Vitamin'}
# {'department': 'Health & Wellness', 'category': 'First Aid', 'item_id': 'ITM10298', 'item_name': 'Any First Ai'}
# {'department': 'Health & Wellness', 'category': 'First Aid', 'item_id': 'ITM10299', 'item_name': 'Partner First Ai'}
# {'department': 'Health & Wellness', 'category': 'First Aid', 'item_id': 'ITM10300', 'item_name': 'Itself First Ai'}
# {'department': 'Health & Wellness', 'category': 'First Aid', 'item_id': 'ITM10301', 'item_name': 'Away First Ai'}
# {'department': 'Health & Wellness', 'category': 'First Aid', 'item_id': 'ITM10302', 'item_name': 'Imagine First Ai'}
# {'department': 'Health & Wellness', 'category': 'First Aid', 'item_id': 'ITM10303', 'item_name': 'Ball First Ai'}
# {'department': 'Health & Wellness', 'category': 'First Aid', 'item_id': 'ITM10304', 'item_name': 'Very First Ai'}
# {'department': 'Health & Wellness', 'category': 'First Aid', 'item_id': 'ITM10305', 'item_name': 'Traditional First Ai'}
# {'department': 'Health & Wellness', 'category': 'First Aid', 'item_id': 'ITM10306', 'item_name': 'Position First Ai'}
# {'department': 'Health & Wellness', 'category': 'First Aid', 'item_id': 'ITM10307', 'item_name': 'Argue First Ai'}
# {'department': 'Health & Wellness', 'category': 'First Aid', 'item_id': 'ITM10308', 'item_name': 'Draw First Ai'}
# {'department': 'Health & Wellness', 'category': 'First Aid', 'item_id': 'ITM10309', 'item_name': 'Clear First Ai'}
# {'department': 'Health & Wellness', 'category': 'First Aid', 'item_id': 'ITM10310', 'item_name': 'Assume First Ai'}
# {'department': 'Health & Wellness', 'category': 'First Aid', 'item_id': 'ITM10311', 'item_name': 'Green First Ai'}
# {'department': 'Health & Wellness', 'category': 'First Aid', 'item_id': 'ITM10312', 'item_name': 'How First Ai'}
# {'department': 'Health & Wellness', 'category': 'First Aid', 'item_id': 'ITM10313', 'item_name': 'Instead First Ai'}
# {'department': 'Health & Wellness', 'category': 'First Aid', 'item_id': 'ITM10314', 'item_name': 'Side First Ai'}
# {'department': 'Health & Wellness', 'category': 'Sanitary Products', 'item_id': 'ITM10315', 'item_name': 'Purpose Sanitary Product'}
# {'department': 'Health & Wellness', 'category': 'Sanitary Products', 'item_id': 'ITM10316', 'item_name': 'Long Sanitary Product'}
# {'department': 'Health & Wellness', 'category': 'Sanitary Products', 'item_id': 'ITM10317', 'item_name': 'Home Sanitary Product'}
# {'department': 'Health & Wellness', 'category': 'Sanitary Products', 'item_id': 'ITM10318', 'item_name': 'Too Sanitary Product'}
# {'department': 'Health & Wellness', 'category': 'Sanitary Products', 'item_id': 'ITM10319', 'item_name': 'Want Sanitary Product'}
# {'department': 'Health & Wellness', 'category': 'Sanitary Products', 'item_id': 'ITM10320', 'item_name': 'Care Sanitary Product'}
# {'department': 'Health & Wellness', 'category': 'Sanitary Products', 'item_id': 'ITM10321', 'item_name': 'Affect Sanitary Product'}
# {'department': 'Health & Wellness', 'category': 'Sanitary Products', 'item_id': 'ITM10322', 'item_name': 'Inside Sanitary Product'}
# {'department': 'Health & Wellness', 'category': 'Sanitary Products', 'item_id': 'ITM10323', 'item_name': 'Unit Sanitary Product'}
# {'department': 'Health & Wellness', 'category': 'Sanitary Products', 'item_id': 'ITM10324', 'item_name': 'Own Sanitary Product'}
# {'department': 'Health & Wellness', 'category': 'Sanitary Products', 'item_id': 'ITM10325', 'item_name': 'Technology Sanitary Product'}
# {'department': 'Health & Wellness', 'category': 'Sanitary Products', 'item_id': 'ITM10326', 'item_name': 'Lot Sanitary Product'}
# {'department': 'Health & Wellness', 'category': 'Sanitary Products', 'item_id': 'ITM10327', 'item_name': 'General Sanitary Product'}
# {'department': 'Health & Wellness', 'category': 'Sanitary Products', 'item_id': 'ITM10328', 'item_name': 'Large Sanitary Product'}
# {'department': 'Health & Wellness', 'category': 'Sanitary Products', 'item_id': 'ITM10329', 'item_name': 'Media Sanitary Product'}
# {'department': 'Health & Wellness', 'category': 'Sanitary Products', 'item_id': 'ITM10330', 'item_name': 'Risk Sanitary Product'}
# {'department': 'Health & Wellness', 'category': 'Sanitary Products', 'item_id': 'ITM10331', 'item_name': 'Along Sanitary Product'}
# {'department': 'Health & Wellness', 'category': 'Sanitary Products', 'item_id': 'ITM10332', 'item_name': 'Area Sanitary Product'}
# {'department': 'Packaged Foods', 'category': 'Instant Noodles', 'item_id': 'ITM10333', 'item_name': 'Decision Instant Noodle'}
# {'department': 'Packaged Foods', 'category': 'Instant Noodles', 'item_id': 'ITM10334', 'item_name': 'Young Instant Noodle'}
# {'department': 'Packaged Foods', 'category': 'Instant Noodles', 'item_id': 'ITM10335', 'item_name': 'Officer Instant Noodle'}
# {'department': 'Packaged Foods', 'category': 'Instant Noodles', 'item_id': 'ITM10336', 'item_name': 'Matter Instant Noodle'}
# {'department': 'Packaged Foods', 'category': 'Instant Noodles', 'item_id': 'ITM10337', 'item_name': 'Evidence Instant Noodle'}
# {'department': 'Packaged Foods', 'category': 'Instant Noodles', 'item_id': 'ITM10338', 'item_name': 'Set Instant Noodle'}
# {'department': 'Packaged Foods', 'category': 'Instant Noodles', 'item_id': 'ITM10339', 'item_name': 'Perhaps Instant Noodle'}
# {'department': 'Packaged Foods', 'category': 'Instant Noodles', 'item_id': 'ITM10340', 'item_name': 'Meet Instant Noodle'}
# {'department': 'Packaged Foods', 'category': 'Instant Noodles', 'item_id': 'ITM10341', 'item_name': 'Sense Instant Noodle'}
# {'department': 'Packaged Foods', 'category': 'Instant Noodles', 'item_id': 'ITM10342', 'item_name': 'Generation Instant Noodle'}
# {'department': 'Packaged Foods', 'category': 'Instant Noodles', 'item_id': 'ITM10343', 'item_name': 'South Instant Noodle'}
# {'department': 'Packaged Foods', 'category': 'Instant Noodles', 'item_id': 'ITM10344', 'item_name': 'Behind Instant Noodle'}
# {'department': 'Packaged Foods', 'category': 'Instant Noodles', 'item_id': 'ITM10345', 'item_name': 'Should Instant Noodle'}
# {'department': 'Packaged Foods', 'category': 'Instant Noodles', 'item_id': 'ITM10346', 'item_name': 'Each Instant Noodle'}
# {'department': 'Packaged Foods', 'category': 'Instant Noodles', 'item_id': 'ITM10347', 'item_name': 'Improve Instant Noodle'}
# {'department': 'Packaged Foods', 'category': 'Instant Noodles', 'item_id': 'ITM10348', 'item_name': 'Admit Instant Noodle'}
# {'department': 'Packaged Foods', 'category': 'Instant Noodles', 'item_id': 'ITM10349', 'item_name': 'Talk Instant Noodle'}
# {'department': 'Packaged Foods', 'category': 'Ready Meals', 'item_id': 'ITM10350', 'item_name': 'Option Ready Meal'}
# {'department': 'Packaged Foods', 'category': 'Ready Meals', 'item_id': 'ITM10351', 'item_name': 'Last Ready Meal'}
# {'department': 'Packaged Foods', 'category': 'Ready Meals', 'item_id': 'ITM10352', 'item_name': 'See Ready Meal'}
# {'department': 'Packaged Foods', 'category': 'Ready Meals', 'item_id': 'ITM10353', 'item_name': 'Fall Ready Meal'}
# {'department': 'Packaged Foods', 'category': 'Ready Meals', 'item_id': 'ITM10354', 'item_name': 'Range Ready Meal'}
# {'department': 'Packaged Foods', 'category': 'Ready Meals', 'item_id': 'ITM10355', 'item_name': 'Maintain Ready Meal'}
# {'department': 'Packaged Foods', 'category': 'Ready Meals', 'item_id': 'ITM10356', 'item_name': 'Simply Ready Meal'}
# {'department': 'Packaged Foods', 'category': 'Ready Meals', 'item_id': 'ITM10357', 'item_name': 'Together Ready Meal'}
# {'department': 'Packaged Foods', 'category': 'Ready Meals', 'item_id': 'ITM10358', 'item_name': 'Explain Ready Meal'}
# {'department': 'Packaged Foods', 'category': 'Ready Meals', 'item_id': 'ITM10359', 'item_name': 'Think Ready Meal'}
# {'department': 'Packaged Foods', 'category': 'Ready Meals', 'item_id': 'ITM10360', 'item_name': 'Nothing Ready Meal'}
# {'department': 'Packaged Foods', 'category': 'Ready Meals', 'item_id': 'ITM10361', 'item_name': 'Design Ready Meal'}
# {'department': 'Packaged Foods', 'category': 'Ready Meals', 'item_id': 'ITM10362', 'item_name': 'Than Ready Meal'}
# {'department': 'Packaged Foods', 'category': 'Ready Meals', 'item_id': 'ITM10363', 'item_name': 'Page Ready Meal'}
# {'department': 'Packaged Foods', 'category': 'Ready Meals', 'item_id': 'ITM10364', 'item_name': 'Alone Ready Meal'}
# {'department': 'Packaged Foods', 'category': 'Ready Meals', 'item_id': 'ITM10365', 'item_name': 'Need Ready Meal'}
# {'department': 'Packaged Foods', 'category': 'Ready Meals', 'item_id': 'ITM10366', 'item_name': 'However Ready Meal'}
# {'department': 'Packaged Foods', 'category': 'Ready Meals', 'item_id': 'ITM10367', 'item_name': 'Party Ready Meal'}
# {'department': 'Packaged Foods', 'category': 'Canned Goods', 'item_id': 'ITM10368', 'item_name': 'Dog Canned Good'}
# {'department': 'Packaged Foods', 'category': 'Canned Goods', 'item_id': 'ITM10369', 'item_name': 'Of Canned Good'}
# {'department': 'Packaged Foods', 'category': 'Canned Goods', 'item_id': 'ITM10370', 'item_name': 'Future Canned Good'}
# {'department': 'Packaged Foods', 'category': 'Canned Goods', 'item_id': 'ITM10371', 'item_name': 'Work Canned Good'}
# {'department': 'Packaged Foods', 'category': 'Canned Goods', 'item_id': 'ITM10372', 'item_name': 'School Canned Good'}
# {'department': 'Packaged Foods', 'category': 'Canned Goods', 'item_id': 'ITM10373', 'item_name': 'Direction Canned Good'}
# {'department': 'Packaged Foods', 'category': 'Canned Goods', 'item_id': 'ITM10374', 'item_name': 'Hundred Canned Good'}
# {'department': 'Packaged Foods', 'category': 'Canned Goods', 'item_id': 'ITM10375', 'item_name': 'Worker Canned Good'}
# {'department': 'Packaged Foods', 'category': 'Canned Goods', 'item_id': 'ITM10376', 'item_name': 'Audience Canned Good'}
# {'department': 'Packaged Foods', 'category': 'Canned Goods', 'item_id': 'ITM10377', 'item_name': 'Early Canned Good'}
# {'department': 'Packaged Foods', 'category': 'Cooking Pastes', 'item_id': 'ITM10378', 'item_name': 'Wait Cooking Paste'}
# {'department': 'Packaged Foods', 'category': 'Cooking Pastes', 'item_id': 'ITM10379', 'item_name': 'Hit Cooking Paste'}
# {'department': 'Packaged Foods', 'category': 'Cooking Pastes', 'item_id': 'ITM10380', 'item_name': 'Claim Cooking Paste'}
# {'department': 'Packaged Foods', 'category': 'Cooking Pastes', 'item_id': 'ITM10381', 'item_name': 'All Cooking Paste'}
# {'department': 'Packaged Foods', 'category': 'Cooking Pastes', 'item_id': 'ITM10382', 'item_name': 'Special Cooking Paste'}
# {'department': 'Packaged Foods', 'category': 'Cooking Pastes', 'item_id': 'ITM10383', 'item_name': 'Detail Cooking Paste'}
# {'department': 'Packaged Foods', 'category': 'Cooking Pastes', 'item_id': 'ITM10384', 'item_name': 'Bring Cooking Paste'}
# {'department': 'Packaged Foods', 'category': 'Cooking Pastes', 'item_id': 'ITM10385', 'item_name': 'Article Cooking Paste'}
# {'department': 'Packaged Foods', 'category': 'Cooking Pastes', 'item_id': 'ITM10386', 'item_name': 'Management Cooking Paste'}
# {'department': 'Packaged Foods', 'category': 'Cooking Pastes', 'item_id': 'ITM10387', 'item_name': 'Without Cooking Paste'}
# {'department': 'Packaged Foods', 'category': 'Cooking Pastes', 'item_id': 'ITM10388', 'item_name': 'More Cooking Paste'}
# {'department': 'Packaged Foods', 'category': 'Cooking Pastes', 'item_id': 'ITM10389', 'item_name': 'Protect Cooking Paste'}
# {'department': 'Packaged Foods', 'category': 'Cooking Pastes', 'item_id': 'ITM10390', 'item_name': 'Anyone Cooking Paste'}
# {'department': 'Baby Care', 'category': 'Diapers', 'item_id': 'ITM10391', 'item_name': 'Sit Diaper'}
# {'department': 'Baby Care', 'category': 'Diapers', 'item_id': 'ITM10392', 'item_name': 'Reveal Diaper'}
# {'department': 'Baby Care', 'category': 'Diapers', 'item_id': 'ITM10393', 'item_name': 'Born Diaper'}
# {'department': 'Baby Care', 'category': 'Diapers', 'item_id': 'ITM10394', 'item_name': 'Exactly Diaper'}
# {'department': 'Baby Care', 'category': 'Diapers', 'item_id': 'ITM10395', 'item_name': 'Tell Diaper'}
# {'department': 'Baby Care', 'category': 'Diapers', 'item_id': 'ITM10396', 'item_name': 'Song Diaper'}
# {'department': 'Baby Care', 'category': 'Diapers', 'item_id': 'ITM10397', 'item_name': 'Fact Diaper'}
# {'department': 'Baby Care', 'category': 'Diapers', 'item_id': 'ITM10398', 'item_name': 'Authority Diaper'}
# {'department': 'Baby Care', 'category': 'Diapers', 'item_id': 'ITM10399', 'item_name': 'Theory Diaper'}
# {'department': 'Baby Care', 'category': 'Diapers', 'item_id': 'ITM10400', 'item_name': 'Your Diaper'}
# {'department': 'Baby Care', 'category': 'Diapers', 'item_id': 'ITM10401', 'item_name': 'Nice Diaper'}
# {'department': 'Baby Care', 'category': 'Diapers', 'item_id': 'ITM10402', 'item_name': 'Population Diaper'}
# {'department': 'Baby Care', 'category': 'Diapers', 'item_id': 'ITM10403', 'item_name': 'Space Diaper'}
# {'department': 'Baby Care', 'category': 'Diapers', 'item_id': 'ITM10404', 'item_name': 'Subject Diaper'}
# {'department': 'Baby Care', 'category': 'Diapers', 'item_id': 'ITM10405', 'item_name': 'Allow Diaper'}
# {'department': 'Baby Care', 'category': 'Diapers', 'item_id': 'ITM10406', 'item_name': 'Baby Diaper'}
# {'department': 'Baby Care', 'category': 'Diapers', 'item_id': 'ITM10407', 'item_name': 'Majority Diaper'}
# {'department': 'Baby Care', 'category': 'Diapers', 'item_id': 'ITM10408', 'item_name': 'View Diaper'}
# {'department': 'Baby Care', 'category': 'Baby Food', 'item_id': 'ITM10409', 'item_name': 'Lose Baby Foo'}
# {'department': 'Baby Care', 'category': 'Baby Food', 'item_id': 'ITM10410', 'item_name': 'Ok Baby Foo'}
# {'department': 'Baby Care', 'category': 'Baby Food', 'item_id': 'ITM10411', 'item_name': 'Success Baby Foo'}
# {'department': 'Baby Care', 'category': 'Baby Food', 'item_id': 'ITM10412', 'item_name': 'Six Baby Foo'}
# {'department': 'Baby Care', 'category': 'Baby Food', 'item_id': 'ITM10413', 'item_name': 'Citizen Baby Foo'}
# {'department': 'Baby Care', 'category': 'Baby Food', 'item_id': 'ITM10414', 'item_name': 'Sing Baby Foo'}
# {'department': 'Baby Care', 'category': 'Baby Food', 'item_id': 'ITM10415', 'item_name': 'Hold Baby Foo'}
# {'department': 'Baby Care', 'category': 'Baby Food', 'item_id': 'ITM10416', 'item_name': 'Better Baby Foo'}
# {'department': 'Baby Care', 'category': 'Baby Food', 'item_id': 'ITM10417', 'item_name': 'Question Baby Foo'}
# {'department': 'Baby Care', 'category': 'Baby Food', 'item_id': 'ITM10418', 'item_name': 'Move Baby Foo'}
# {'department': 'Baby Care', 'category': 'Baby Food', 'item_id': 'ITM10419', 'item_name': 'Leave Baby Foo'}
# {'department': 'Baby Care', 'category': 'Baby Food', 'item_id': 'ITM10420', 'item_name': 'Everybody Baby Foo'}
# {'department': 'Baby Care', 'category': 'Baby Food', 'item_id': 'ITM10421', 'item_name': 'Ago Baby Foo'}
# {'department': 'Baby Care', 'category': 'Baby Food', 'item_id': 'ITM10422', 'item_name': 'Break Baby Foo'}
# {'department': 'Baby Care', 'category': 'Baby Food', 'item_id': 'ITM10423', 'item_name': 'Chair Baby Foo'}
# {'department': 'Baby Care', 'category': 'Baby Food', 'item_id': 'ITM10424', 'item_name': 'Interview Baby Foo'}
# {'department': 'Baby Care', 'category': 'Baby Food', 'item_id': 'ITM10425', 'item_name': 'Road Baby Foo'}
# {'department': 'Baby Care', 'category': 'Baby Food', 'item_id': 'ITM10426', 'item_name': 'Peace Baby Foo'}
# {'department': 'Baby Care', 'category': 'Baby Lotion', 'item_id': 'ITM10427', 'item_name': 'War Baby Lotio'}
# {'department': 'Baby Care', 'category': 'Baby Lotion', 'item_id': 'ITM10428', 'item_name': 'Follow Baby Lotio'}
# {'department': 'Baby Care', 'category': 'Baby Lotion', 'item_id': 'ITM10429', 'item_name': 'Practice Baby Lotio'}
# {'department': 'Baby Care', 'category': 'Baby Lotion', 'item_id': 'ITM10430', 'item_name': 'Indeed Baby Lotio'}
# {'department': 'Baby Care', 'category': 'Baby Lotion', 'item_id': 'ITM10431', 'item_name': 'Loss Baby Lotio'}
# {'department': 'Baby Care', 'category': 'Baby Lotion', 'item_id': 'ITM10432', 'item_name': 'Forward Baby Lotio'}
# {'department': 'Baby Care', 'category': 'Baby Lotion', 'item_id': 'ITM10433', 'item_name': 'Wife Baby Lotio'}
# {'department': 'Baby Care', 'category': 'Baby Lotion', 'item_id': 'ITM10434', 'item_name': 'Current Baby Lotio'}
# {'department': 'Baby Care', 'category': 'Baby Lotion', 'item_id': 'ITM10435', 'item_name': 'Happy Baby Lotio'}
# {'department': 'Baby Care', 'category': 'Baby Lotion', 'item_id': 'ITM10436', 'item_name': 'Tonight Baby Lotio'}
# {'department': 'Baby Care', 'category': 'Wipes', 'item_id': 'ITM10437', 'item_name': 'Else Wipe'}
# {'department': 'Baby Care', 'category': 'Wipes', 'item_id': 'ITM10438', 'item_name': 'Least Wipe'}
# {'department': 'Baby Care', 'category': 'Wipes', 'item_id': 'ITM10439', 'item_name': 'Painting Wipe'}
# {'department': 'Baby Care', 'category': 'Wipes', 'item_id': 'ITM10440', 'item_name': 'Suddenly Wipe'}
# {'department': 'Baby Care', 'category': 'Wipes', 'item_id': 'ITM10441', 'item_name': 'Beyond Wipe'}
# {'department': 'Baby Care', 'category': 'Wipes', 'item_id': 'ITM10442', 'item_name': 'Total Wipe'}
# {'department': 'Baby Care', 'category': 'Wipes', 'item_id': 'ITM10443', 'item_name': 'Street Wipe'}
# {'department': 'Baby Care', 'category': 'Wipes', 'item_id': 'ITM10444', 'item_name': 'Let Wipe'}
# {'department': 'Baby Care', 'category': 'Wipes', 'item_id': 'ITM10445', 'item_name': 'Exist Wipe'}
# {'department': 'Baby Care', 'category': 'Wipes', 'item_id': 'ITM10446', 'item_name': 'Myself Wipe'}
# {'department': 'Baby Care', 'category': 'Wipes', 'item_id': 'ITM10447', 'item_name': 'She Wipe'}
# {'department': 'Baby Care', 'category': 'Wipes', 'item_id': 'ITM10448', 'item_name': 'Increase Wipe'}
# {'department': 'Baby Care', 'category': 'Wipes', 'item_id': 'ITM10449', 'item_name': 'Statement Wipe'}
# {'department': 'Baby Care', 'category': 'Wipes', 'item_id': 'ITM10450', 'item_name': 'Policy Wipe'}
# {'department': 'Baby Care', 'category': 'Wipes', 'item_id': 'ITM10451', 'item_name': 'Bit Wipe'}
# {'department': 'Baby Care', 'category': 'Wipes', 'item_id': 'ITM10452', 'item_name': 'Often Wipe'}
# {'department': 'Baby Care', 'category': 'Wipes', 'item_id': 'ITM10453', 'item_name': 'Pattern Wipe'}
# {'department': 'Baby Care', 'category': 'Wipes', 'item_id': 'ITM10454', 'item_name': 'Late Wipe'}
# {'department': 'Baby Care', 'category': 'Wipes', 'item_id': 'ITM10455', 'item_name': 'Even Wipe'}
# {'department': 'Baby Care', 'category': 'Wipes', 'item_id': 'ITM10456', 'item_name': 'Back Wipe'}
# {'department': 'Pet Care', 'category': 'Pet Food', 'item_id': 'ITM10457', 'item_name': 'Add Pet Foo'}
# {'department': 'Pet Care', 'category': 'Pet Food', 'item_id': 'ITM10458', 'item_name': 'Certain Pet Foo'}
# {'department': 'Pet Care', 'category': 'Pet Food', 'item_id': 'ITM10459', 'item_name': 'Listen Pet Foo'}
# {'department': 'Pet Care', 'category': 'Pet Food', 'item_id': 'ITM10460', 'item_name': 'In Pet Foo'}
# {'department': 'Pet Care', 'category': 'Pet Food', 'item_id': 'ITM10461', 'item_name': 'Child Pet Foo'}
# {'department': 'Pet Care', 'category': 'Pet Food', 'item_id': 'ITM10462', 'item_name': 'Note Pet Foo'}
# {'department': 'Pet Care', 'category': 'Pet Food', 'item_id': 'ITM10463', 'item_name': 'Cost Pet Foo'}
# {'department': 'Pet Care', 'category': 'Pet Food', 'item_id': 'ITM10464', 'item_name': 'Order Pet Foo'}
# {'department': 'Pet Care', 'category': 'Pet Food', 'item_id': 'ITM10465', 'item_name': 'People Pet Foo'}
# {'department': 'Pet Care', 'category': 'Pet Food', 'item_id': 'ITM10466', 'item_name': 'Cultural Pet Foo'}
# {'department': 'Pet Care', 'category': 'Pet Food', 'item_id': 'ITM10467', 'item_name': 'Tax Pet Foo'}
# {'department': 'Pet Care', 'category': 'Pet Food', 'item_id': 'ITM10468', 'item_name': 'Key Pet Foo'}
# {'department': 'Pet Care', 'category': 'Pet Food', 'item_id': 'ITM10469', 'item_name': 'Operation Pet Foo'}
# {'department': 'Pet Care', 'category': 'Pet Food', 'item_id': 'ITM10470', 'item_name': 'Measure Pet Foo'}
# {'department': 'Pet Care', 'category': 'Pet Food', 'item_id': 'ITM10471', 'item_name': 'Recently Pet Foo'}
# {'department': 'Pet Care', 'category': 'Pet Shampoo', 'item_id': 'ITM10472', 'item_name': 'Feeling Pet Shampo'}
# {'department': 'Pet Care', 'category': 'Pet Shampoo', 'item_id': 'ITM10473', 'item_name': 'Mind Pet Shampo'}
# {'department': 'Pet Care', 'category': 'Pet Shampoo', 'item_id': 'ITM10474', 'item_name': 'This Pet Shampo'}
# {'department': 'Pet Care', 'category': 'Pet Shampoo', 'item_id': 'ITM10475', 'item_name': 'Chance Pet Shampo'}
# {'department': 'Pet Care', 'category': 'Pet Shampoo', 'item_id': 'ITM10476', 'item_name': 'Positive Pet Shampo'}
# {'department': 'Pet Care', 'category': 'Pet Shampoo', 'item_id': 'ITM10477', 'item_name': 'Certainly Pet Shampo'}
# {'department': 'Pet Care', 'category': 'Pet Shampoo', 'item_id': 'ITM10478', 'item_name': 'Car Pet Shampo'}
# {'department': 'Pet Care', 'category': 'Pet Shampoo', 'item_id': 'ITM10479', 'item_name': 'Their Pet Shampo'}
# {'department': 'Pet Care', 'category': 'Pet Shampoo', 'item_id': 'ITM10480', 'item_name': 'Window Pet Shampo'}
# {'department': 'Pet Care', 'category': 'Pet Shampoo', 'item_id': 'ITM10481', 'item_name': 'Store Pet Shampo'}
# {'department': 'Pet Care', 'category': 'Pet Shampoo', 'item_id': 'ITM10482', 'item_name': 'Yet Pet Shampo'}
# {'department': 'Pet Care', 'category': 'Pet Shampoo', 'item_id': 'ITM10483', 'item_name': 'Him Pet Shampo'}
# {'department': 'Pet Care', 'category': 'Pet Shampoo', 'item_id': 'ITM10484', 'item_name': 'Report Pet Shampo'}
# {'department': 'Pet Care', 'category': 'Pet Shampoo', 'item_id': 'ITM10485', 'item_name': 'It Pet Shampo'}
# {'department': 'Pet Care', 'category': 'Pet Shampoo', 'item_id': 'ITM10486', 'item_name': 'Catch Pet Shampo'}
# {'department': 'Pet Care', 'category': 'Pet Shampoo', 'item_id': 'ITM10487', 'item_name': 'Understand Pet Shampo'}
# {'department': 'Pet Care', 'category': 'Pet Toys', 'item_id': 'ITM10488', 'item_name': 'Though Pet Toy'}
# {'department': 'Pet Care', 'category': 'Pet Toys', 'item_id': 'ITM10489', 'item_name': 'Thousand Pet Toy'}
# {'department': 'Pet Care', 'category': 'Pet Toys', 'item_id': 'ITM10490', 'item_name': 'Down Pet Toy'}
# {'department': 'Pet Care', 'category': 'Pet Toys', 'item_id': 'ITM10491', 'item_name': 'One Pet Toy'}
# {'department': 'Pet Care', 'category': 'Pet Toys', 'item_id': 'ITM10492', 'item_name': 'Represent Pet Toy'}
# {'department': 'Pet Care', 'category': 'Pet Toys', 'item_id': 'ITM10493', 'item_name': 'Material Pet Toy'}
# {'department': 'Pet Care', 'category': 'Pet Toys', 'item_id': 'ITM10494', 'item_name': 'Serious Pet Toy'}
# {'department': 'Pet Care', 'category': 'Pet Toys', 'item_id': 'ITM10495', 'item_name': 'Challenge Pet Toy'}
# {'department': 'Pet Care', 'category': 'Pet Toys', 'item_id': 'ITM10496', 'item_name': 'Read Pet Toy'}
# {'department': 'Pet Care', 'category': 'Pet Toys', 'item_id': 'ITM10497', 'item_name': 'Year Pet Toy'}
# {'department': 'Pet Care', 'category': 'Pet Toys', 'item_id': 'ITM10498', 'item_name': 'Everything Pet Toy'}
# {'department': 'Pet Care', 'category': 'Pet Toys', 'item_id': 'ITM10499', 'item_name': 'Take Pet Toy'}
# {'department': 'Stationery & Supplies', 'category': 'Pens', 'item_id': 'ITM10500', 'item_name': 'Coach Pen'}
# {'department': 'Stationery & Supplies', 'category': 'Pens', 'item_id': 'ITM10501', 'item_name': 'Most Pen'}
# {'department': 'Stationery & Supplies', 'category': 'Pens', 'item_id': 'ITM10502', 'item_name': 'Tv Pen'}
# {'department': 'Stationery & Supplies', 'category': 'Pens', 'item_id': 'ITM10503', 'item_name': 'True Pen'}
# {'department': 'Stationery & Supplies', 'category': 'Pens', 'item_id': 'ITM10504', 'item_name': 'Right Pen'}
# {'department': 'Stationery & Supplies', 'category': 'Pens', 'item_id': 'ITM10505', 'item_name': 'East Pen'}
# {'department': 'Stationery & Supplies', 'category': 'Pens', 'item_id': 'ITM10506', 'item_name': 'Staff Pen'}
# {'department': 'Stationery & Supplies', 'category': 'Pens', 'item_id': 'ITM10507', 'item_name': 'Pretty Pen'}
# {'department': 'Stationery & Supplies', 'category': 'Pens', 'item_id': 'ITM10508', 'item_name': 'History Pen'}
# {'department': 'Stationery & Supplies', 'category': 'Pens', 'item_id': 'ITM10509', 'item_name': 'Enjoy Pen'}
# {'department': 'Stationery & Supplies', 'category': 'Pens', 'item_id': 'ITM10510', 'item_name': 'North Pen'}
# {'department': 'Stationery & Supplies', 'category': 'Pens', 'item_id': 'ITM10511', 'item_name': 'Data Pen'}
# {'department': 'Stationery & Supplies', 'category': 'Pens', 'item_id': 'ITM10512', 'item_name': 'Join Pen'}
# {'department': 'Stationery & Supplies', 'category': 'Notebooks', 'item_id': 'ITM10513', 'item_name': 'Front Notebook'}
# {'department': 'Stationery & Supplies', 'category': 'Notebooks', 'item_id': 'ITM10514', 'item_name': 'Pressure Notebook'}
# {'department': 'Stationery & Supplies', 'category': 'Notebooks', 'item_id': 'ITM10515', 'item_name': 'National Notebook'}
# {'department': 'Stationery & Supplies', 'category': 'Notebooks', 'item_id': 'ITM10516', 'item_name': 'Specific Notebook'}
# {'department': 'Stationery & Supplies', 'category': 'Notebooks', 'item_id': 'ITM10517', 'item_name': 'Respond Notebook'}
# {'department': 'Stationery & Supplies', 'category': 'Notebooks', 'item_id': 'ITM10518', 'item_name': 'Toward Notebook'}
# {'department': 'Stationery & Supplies', 'category': 'Notebooks', 'item_id': 'ITM10519', 'item_name': 'Drive Notebook'}
# {'department': 'Stationery & Supplies', 'category': 'Notebooks', 'item_id': 'ITM10520', 'item_name': 'Another Notebook'}
# {'department': 'Stationery & Supplies', 'category': 'Notebooks', 'item_id': 'ITM10521', 'item_name': 'Organization Notebook'}
# {'department': 'Stationery & Supplies', 'category': 'Notebooks', 'item_id': 'ITM10522', 'item_name': 'Sound Notebook'}
# {'department': 'Stationery & Supplies', 'category': 'Glue', 'item_id': 'ITM10523', 'item_name': 'Suffer Glu'}
# {'department': 'Stationery & Supplies', 'category': 'Glue', 'item_id': 'ITM10524', 'item_name': 'After Glu'}
# {'department': 'Stationery & Supplies', 'category': 'Glue', 'item_id': 'ITM10525', 'item_name': 'Spend Glu'}
# {'department': 'Stationery & Supplies', 'category': 'Glue', 'item_id': 'ITM10526', 'item_name': 'Community Glu'}
# {'department': 'Stationery & Supplies', 'category': 'Glue', 'item_id': 'ITM10527', 'item_name': 'Easy Glu'}
# {'department': 'Stationery & Supplies', 'category': 'Glue', 'item_id': 'ITM10528', 'item_name': 'Sort Glu'}
# {'department': 'Stationery & Supplies', 'category': 'Glue', 'item_id': 'ITM10529', 'item_name': 'Opportunity Glu'}
# {'department': 'Stationery & Supplies', 'category': 'Glue', 'item_id': 'ITM10530', 'item_name': 'Natural Glu'}
# {'department': 'Stationery & Supplies', 'category': 'Glue', 'item_id': 'ITM10531', 'item_name': 'Kitchen Glu'}
# {'department': 'Stationery & Supplies', 'category': 'Glue', 'item_id': 'ITM10532', 'item_name': 'Vote Glu'}
# {'department': 'Stationery & Supplies', 'category': 'Glue', 'item_id': 'ITM10533', 'item_name': 'Those Glu'}
# {'department': 'Stationery & Supplies', 'category': 'Glue', 'item_id': 'ITM10534', 'item_name': 'Factor Glu'}
# {'department': 'Stationery & Supplies', 'category': 'Markers', 'item_id': 'ITM10535', 'item_name': 'Memory Marker'}
# {'department': 'Stationery & Supplies', 'category': 'Markers', 'item_id': 'ITM10536', 'item_name': 'Happen Marker'}
# {'department': 'Stationery & Supplies', 'category': 'Markers', 'item_id': 'ITM10537', 'item_name': 'Government Marker'}
# {'department': 'Stationery & Supplies', 'category': 'Markers', 'item_id': 'ITM10538', 'item_name': 'Light Marker'}
# {'department': 'Stationery & Supplies', 'category': 'Markers', 'item_id': 'ITM10539', 'item_name': 'Mouth Marker'}
# {'department': 'Stationery & Supplies', 'category': 'Markers', 'item_id': 'ITM10540', 'item_name': 'Appear Marker'}
# {'department': 'Stationery & Supplies', 'category': 'Markers', 'item_id': 'ITM10541', 'item_name': 'As Marker'}
# {'department': 'Stationery & Supplies', 'category': 'Markers', 'item_id': 'ITM10542', 'item_name': 'Because Marker'}
# {'department': 'Stationery & Supplies', 'category': 'Markers', 'item_id': 'ITM10543', 'item_name': 'Ask Marker'}
# {'department': 'Stationery & Supplies', 'category': 'Markers', 'item_id': 'ITM10544', 'item_name': 'Next Marker'}

# %%
print(f"Inserted {len(df)} rows into SQL Server table 'product_hierarchy'.")
# Out:
# Inserted 545 rows into SQL Server table 'product_hierarchy'.
